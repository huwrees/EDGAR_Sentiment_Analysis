# %%
import edgar_data_processing as edp

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive', 'perc_Uncertainty', 'perc_Litigious', 'perc_Constraining', 'perc_Modal'],
                            z_normalised_cols = ['sentiment_score', 'sentiment1', 'sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive', 'perc_Uncertainty', 'perc_Litigious', 'perc_Constraining', 'perc_Modal'],
                            z_normalised_cols = ['sentiment_score', 'sentiment1', 'sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.516994633273703

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.49731663685152055

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5278276481149012

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.503690036900369

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5053763440860215

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5095057034220533

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.48300536672629696

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.4955116696588869

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.45940959409594095

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.46953405017921146

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5038022813688213

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5134168157423972

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5008976660682226

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.4944649446494465

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.510752688172043

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.4790874524714829

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5080500894454383

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.47217235188509876

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.48523985239852396

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.4946236559139785

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.46387832699619774

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5026833631484794

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5224416517055656

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5202952029520295

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.507168458781362

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5171102661596958

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5044722719141324

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.49371633752244165

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5129151291512916

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.510752688172043

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5076045627376425

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5116279069767442

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5080789946140036

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5125448028673835

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.5057034220532319

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive', 'perc_Uncertainty', 'perc_Litigious', 'perc_Constraining', 'perc_Modal'],
                            z_normalised_cols = ['sentiment_score', 'sentiment1', 'sentiment2'],
                            cat_type = 'rel',
                            categories = {'loss':['lessequal',0],'gain':['greater',0]},
                            )

from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

rfc = RandomForestClassifier(n_estimators = 50, max_depth = 4, random_state = 0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# Accuracy score is 0.516994633273703

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative', 'perc_Positive'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5098389982110912

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Negative'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5366726296958855

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            normalised_cols = ['perc_Positive'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5223613595706619

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['perc_Uncertainty'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.49731663685152055

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment_score', 'sentiment1', 'sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5080500894454383

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment_score'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5080500894454383

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment1'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.4937388193202147

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '1daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.4937388193202147

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '2daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.4955116696588869

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '3daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.496309963099631

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '5daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.5125448028673835

# %%
X_train, y_train, X_test, y_test = edp.get_test_train_split(r'C:\Edgar_EC\Archives\data\full_dataset.csv',
                            '10daily_return',
                            z_normalised_cols = ['sentiment2'],
                            cat_type = 'rel',
                            balance_data = True,
                            categories = {0:['lessequal',0],1:['greater',0]},
                            )

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score

kmeans = KMeans(n_clusters=2)

kmeans.fit(X_train, y_train)
y_pred = kmeans.predict(X_test)

cm = confusion_matrix(y_test, y_pred)

cm_plot = ConfusionMatrixDisplay(cm)
cm_plot.plot(cmap="OrRd")
plt.show()

acc_score = accuracy_score(y_test, y_pred)
print(f'Accuracy score is {acc_score}')
# Out:
# c:\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Accuracy score is 0.49429657794676807
